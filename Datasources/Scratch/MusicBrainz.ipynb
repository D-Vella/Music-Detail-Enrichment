# %% [markdown]
# Documentaion link: https://python-musicbrainzngs.readthedocs.io/en/v0.7.1/usage/

# %%
# %pip install musicbrainzngs pycountry --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import musicbrainzngs as mb
mb.set_useragent("Music Detail Enrichment", "0.1", "https://github.com/D-Vella/music-detail-enrichment")
test_artist_name = "Senses"
result = mb.search_artists(test_artist_name, limit=10)

# %%
cleaned_results = []
for artist in result['artist-list']:
    cleaned_results.append({
        'id': artist['id'],
        'name': artist['name'],
        'score': int(artist.get('ext:score', 0)),
        'type': artist.get('type', 'Unknown')
    })

# %%
# Filter artists based on confidence threshold
filtered_artists = [artist for artist in cleaned_results if artist['score'] >= 85]

#Filter artists based on type (only consider artists and groups)
filtered_artists = [artist for artist in filtered_artists if artist['type'] in ['Person', 'Group']]

# %%
import json
print(json.dumps(filtered_artists, indent=2))
# Out:
# [
#   {
#     "id": "5a14df24-bc1a-4e88-9cc4-fa71eda331da",
#     "name": "Senses",
#     "score": 100,
#     "type": "Person"
#   },
#   {
#     "id": "e911226c-7748-43d3-8c97-4aba8a00149f",
#     "name": "senses",
#     "score": 97,
#     "type": "Group"
#   },
#   {
#     "id": "b4946461-dacb-4aa9-a77c-7b3231317794",
#     "name": "Senses Fail",
#     "score": 97,
#     "type": "Group"
#   },
#   {
#     "id": "31c1a979-4e6b-4c4d-bb22-9c2dd8c3d36f",
#     "name": "Senses",
#     "score": 96,
#     "type": "Person"
#   },
#   {
#     "id": "9941e53e-601b-4fc3-9d08-6bc770c4c65c",
#     "name": "Senses",
#     "score": 94,
#     "type": "Group"
#   },
#   {
#     "id": "c5023415-17ab-4cca-b6d0-5d18ea4f6d94",
#     "name": "Senses",
#     "score": 94,
#     "type": "Person"
#   },
#   {
#     "id": "74c6306c-9ec2-4a54-9686-e7d19d8d8166",
#     "name": "Senses",
#     "score": 93,
#     "type": "Group"
#   },
#   {
#     "id": "56a950cd-dce6-474a-8fdd-6e292d2e595d",
#     "name": "Senses",
#     "score": 93,
#     "type": "Group"
#   }
# ]

# %%
print(json.dumps(result, indent=2))

# %%
result = mb.search_artists(test_artist_name, limit=10)
cleaned_results = []
for artist in result['artist-list']:
    cleaned_results.append({
        'id': artist['id'],
        'name': artist['name'],
        'score': artist.get('ext:score', 0)
    })
for artist in cleaned_results:
    if int(artist['score']) >= 85:
        print(f"{artist['id']}: {artist['name']} - {artist['score']}")

# %%
import json

artist_id = "3ef77bdc-b1ce-4e44-aa4b-acfa763c5284"
try:
    result = mb.get_artist_by_id(artist_id,includes=["release-groups","url-rels","tags"],release_type=["album"])
except mb.WebServiceError as exc:
    print("Something went wrong with the request: %s" % exc)
else:
    artist = result["artist"]
    tags = artist["tag-list"]
    links = artist["url-relation-list"]

    print(json.dumps(result, indent=4))
# Out:
# {
#     "artist": {
#         "id": "3ef77bdc-b1ce-4e44-aa4b-acfa763c5284",
#         "type": "Group",
#         "name": "Powerwolf",
#         "sort-name": "Powerwolf",
#         "country": "DE",
#         "area": {
#             "id": "40475c77-63ee-4296-95c6-ed2a1c84e311",
#             "name": "Saarbr\u00fccken",
#             "sort-name": "Saarbr\u00fccken"
#         },
#         "begin-area": {
#             "id": "40475c77-63ee-4296-95c6-ed2a1c84e311",
#             "name": "Saarbr\u00fccken",
#             "sort-name": "Saarbr\u00fccken"
#         },
#         "isni-list": [
#             "0000000092524370"
#         ],
#         "life-span": {
#             "begin": "2003"
#         },
#         "release-group-list": [
#             {
#                 "id": "d29a7491-5764-3579-a66a-731651f01433",
#                 "type": "Album",
#                 "title": "Return in Bloodred",
#                 "first-release-date": "2005-04-04",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "german"
#                     },
#                     {
#                         "count": "1",
#                         "name": "germany"
#                     },
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "105b6146-9208-33b4-880a-4f6a287196f8",
#                 "type": "Album",
#                 "title": "Lupus Dei",
#                 "first-release-date": "2007-05-04",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "1\u20134 wochen"
#                     },
#                     {
#                         "count": "2",
#                         "name": "german"
#                     },
#                     {
#                         "count": "2",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "62a3e315-8ebb-3b87-a9ac-55742701d40c",
#                 "type": "Album",
#                 "title": "Bible of the Beast",
#                 "first-release-date": "2009-04-27",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "germany"
#                     },
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "d85995c7-bed5-46e2-93a0-ba5e495569c4",
#                 "type": "Album",
#                 "title": "Blood of the Saints",
#                 "first-release-date": "2011-07-29",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "1\u20134 wochen"
#                     },
#                     {
#                         "count": "1",
#                         "name": "german"
#                     },
#                     {
#                         "count": "1",
#                         "name": "germany"
#                     },
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "47c41871-b536-40a9-bf04-bd82f3a0a89e",
#                 "type": "Album",
#                 "title": "Preachers of the Night",
#                 "first-release-date": "2013-06-28",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "germany"
#                     },
#                     {
#                         "count": "3",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "6c2e4b32-185a-42da-9891-a7a93d2b9adf",
#                 "type": "Album",
#                 "title": "Blessed & Possessed",
#                 "first-release-date": "2015-07-17",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "7b757ff3-5bbd-4f1c-83ef-6970ba01d202",
#                 "type": "Album",
#                 "title": "The Sacrament of Sin",
#                 "first-release-date": "2018-07-20",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "german"
#                     },
#                     {
#                         "count": "1",
#                         "name": "germany"
#                     },
#                     {
#                         "count": "2",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "bca83d90-f6d2-4228-ae44-fb6ab67f31ea",
#                 "type": "Album",
#                 "title": "Metallum Nostrum",
#                 "first-release-date": "2019-01-11",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "5fd8a290-6a49-4e5d-b09e-7279388765ca",
#                 "type": "Album",
#                 "title": "The Symphony of Sin",
#                 "first-release-date": "2020-03-13",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "c268f040-6f4b-4a0e-93e9-88a39366875c",
#                 "type": "Album",
#                 "title": "Call of the Wild",
#                 "first-release-date": "2021-07-16",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "2",
#                         "name": "heavy metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "047bf193-e113-4d00-b468-f28631137f89",
#                 "type": "Album",
#                 "title": "Missa Cantorem I",
#                 "first-release-date": "2021-07-16",
#                 "primary-type": "Album"
#             },
#             {
#                 "id": "e2676044-7fe6-4c26-ab7f-c86e6fd72382",
#                 "type": "Album",
#                 "title": "Missa Cantorem II",
#                 "first-release-date": "2022-11-11",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "f005ec16-688b-4598-8e89-5ffcac04c297",
#                 "type": "Album",
#                 "title": "Interludium",
#                 "first-release-date": "2023-04-06",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "1\u20134 wochen"
#                     },
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "symphonic metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "ca0d7fa4-2e42-4902-a7e1-7a26f63ca307",
#                 "type": "Album",
#                 "title": "Wake Up the Wicked",
#                 "first-release-date": "2024-07-26",
#                 "primary-type": "Album",
#                 "tag-list": [
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "2cda351a-0117-4c22-830f-1512defccc20",
#                 "type": "Compilation",
#                 "title": "Trinity in Black \u2013 The Holy Anthology of Hymns for Praise of Heavy Metal",
#                 "first-release-date": "2011-05-06",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Compilation"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "8d6dab60-eafd-4d18-a59e-3f9bd3851df7",
#                 "type": "Compilation",
#                 "title": "The History of Heresy I 2004\u20132008",
#                 "first-release-date": "2014-05-23",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Compilation"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "b746fe08-03c4-41cf-857d-77fef254ef5e",
#                 "type": "Compilation",
#                 "title": "The History of Heresy II 2009\u20132012",
#                 "first-release-date": "2014-10-24",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Compilation"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "531c6ef5-697f-40fd-b9c7-a1a8dafc34f4",
#                 "type": "Compilation",
#                 "title": "The Collection",
#                 "first-release-date": "2015",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Compilation"
#                 ]
#             },
#             {
#                 "id": "18106646-a94a-4710-9be7-94986aa3158c",
#                 "type": "Compilation",
#                 "title": "Best of the Blessed",
#                 "first-release-date": "2020-07-03",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Compilation"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "symphonic metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "848243b0-e0e7-46a9-b2b3-4526866350d5",
#                 "type": "Live",
#                 "title": "The Metal Mass Live",
#                 "first-release-date": "2016-07-29",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "5+ wochen"
#                     },
#                     {
#                         "count": "1",
#                         "name": "english"
#                     },
#                     {
#                         "count": "1",
#                         "name": "live"
#                     },
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "2",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "8ec0727e-797b-41f8-ab04-f9a926b5b957",
#                 "type": "Live",
#                 "title": "Preaching at the Breeze",
#                 "first-release-date": "2017-01-06",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             },
#             {
#                 "id": "5877726e-6779-4178-918d-2e01f8da6fc2",
#                 "type": "Live",
#                 "title": "Live at Masters of Rock",
#                 "first-release-date": "2019-10-08",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "653b73ca-eaa0-44dc-9c67-dab443982378",
#                 "type": "Live",
#                 "title": "Hallowed Be the Holy Ground: Live at Wacken 2019",
#                 "first-release-date": "2022-07-08",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "0f0d7636-31e1-4993-b708-b5079326d90c",
#                 "type": "Live",
#                 "title": "The Monumental Mass: A Cinematic Metal Event",
#                 "first-release-date": "2022-07-08",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "5+ wochen"
#                     },
#                     {
#                         "count": "1",
#                         "name": "english"
#                     },
#                     {
#                         "count": "1",
#                         "name": "german"
#                     },
#                     {
#                         "count": "1",
#                         "name": "metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     }
#                 ]
#             },
#             {
#                 "id": "9d3d0d43-aeea-4fc7-9ba0-27adfbfa514d",
#                 "type": "Live",
#                 "title": "Wildlive: Live at Olympiahalle",
#                 "first-release-date": "2026-02-13",
#                 "primary-type": "Album",
#                 "secondary-type-list": [
#                     "Live"
#                 ],
#                 "tag-list": [
#                     {
#                         "count": "1",
#                         "name": "1\u20134 wochen"
#                     },
#                     {
#                         "count": "1",
#                         "name": "heavy metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "laut.de"
#                     },
#                     {
#                         "count": "1",
#                         "name": "live"
#                     },
#                     {
#                         "count": "1",
#                         "name": "offizielle charts"
#                     },
#                     {
#                         "count": "1",
#                         "name": "power metal"
#                     },
#                     {
#                         "count": "1",
#                         "name": "rock"
#                     }
#                 ]
#             }
#         ],
#         "release-group-count": 27,
#         "url-relation-list": [
#             {
#                 "type": "allmusic",
#                 "type-id": "6b3e3c85-0002-4f34-aca6-80ace0d7e846",
#                 "target": "https://www.allmusic.com/artist/mn0000518763",
#                 "direction": "forward"
#             },
#             {
#                 "type": "bandcamp",
#                 "type-id": "c550166e-0548-4a18-b1d4-e2ae423a3e88",
#                 "target": "https://powerwolf.bandcamp.com/",
#                 "direction": "forward"
#             },
#             {
#                 "type": "bandsintown",
#                 "type-id": "ea45ed3d-2d5e-456e-8c32-94b6f51426e2",
#                 "target": "https://www.bandsintown.com/a/66273",
#                 "direction": "forward"
#             },
#             {
#                 "type": "BBC Music page",
#                 "type-id": "d028a975-000c-4525-9333-d3c8425e4b54",
#                 "target": "https://www.bbc.co.uk/music/artists/3ef77bdc-b1ce-4e44-aa4b-acfa763c5284",
#                 "direction": "forward",
#                 "end": "2020-11-19",
#                 "ended": "true"
#             },
#             {
#                 "type": "discogs",
#                 "type-id": "04a5b104-a4c2-4bac-99a1-7b837c37d9e4",
#                 "target": "https://www.discogs.com/artist/816855",
#                 "direction": "forward"
#             },
#             {
#                 "type": "free streaming",
#                 "type-id": "769085a1-c2f7-4c24-a532-2375a77693bd",
#                 "target": "https://open.spotify.com/artist/5HFkc3t0HYETL4JeEbDB1v",
#                 "direction": "forward"
#             },
#             {
#                 "type": "free streaming",
#                 "type-id": "769085a1-c2f7-4c24-a532-2375a77693bd",
#                 "target": "https://tidal.com/artist/3545381",
#                 "direction": "forward"
#             },
#             {
#                 "type": "free streaming",
#                 "type-id": "769085a1-c2f7-4c24-a532-2375a77693bd",
#                 "target": "https://www.deezer.com/artist/428405",
#                 "direction": "forward"
#             },
#             {
#                 "type": "free streaming",
#                 "type-id": "769085a1-c2f7-4c24-a532-2375a77693bd",
#                 "target": "http://www.pandora.com/powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "last.fm",
#                 "type-id": "08db8098-c0df-4b78-82c3-c8697b4bba7f",
#                 "target": "https://www.last.fm/music/Powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "lyrics",
#                 "type-id": "e4d73442-3762-45a8-905c-401da65544ed",
#                 "target": "https://genius.com/artists/Powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "lyrics",
#                 "type-id": "e4d73442-3762-45a8-905c-401da65544ed",
#                 "target": "https://www.musixmatch.com/artist/Powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "myspace",
#                 "type-id": "bac47923-ecde-4b59-822e-d08f0cd10156",
#                 "target": "https://myspace.com/powerwolfmetal",
#                 "direction": "forward"
#             },
#             {
#                 "type": "official homepage",
#                 "type-id": "fe33d22f-c3b0-4d68-bd53-a856badf2b15",
#                 "target": "http://www.powerwolf.net/",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://imvdb.com/n/powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://rateyourmusic.com/artist/powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://www.metal-archives.com/bands/Powerwolf/34543",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://www.musik-sammler.de/artist/powerwolf/",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://www.spirit-of-metal.com/en/band/Powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://www.whosampled.com/Powerwolf/",
#                 "direction": "forward"
#             },
#             {
#                 "type": "other databases",
#                 "type-id": "d94fb61c-fa20-4e3c-a19a-71a949fb2c55",
#                 "target": "https://www.worldcat.org/identities/lccn-no2009002799",
#                 "direction": "forward"
#             },
#             {
#                 "type": "purchase for download",
#                 "type-id": "f8319a2f-f824-4617-81c8-be6560b3b203",
#                 "target": "https://play.google.com/store/music/artist?id=A3ys3fmeuuibkmusi2k6fgb3nsu",
#                 "direction": "forward",
#                 "end": "2020-10-12",
#                 "ended": "true"
#             },
#             {
#                 "type": "purchase for download",
#                 "type-id": "f8319a2f-f824-4617-81c8-be6560b3b203",
#                 "target": "https://itunes.apple.com/de/artist/id272130237",
#                 "direction": "forward"
#             },
#             {
#                 "type": "purchase for download",
#                 "type-id": "f8319a2f-f824-4617-81c8-be6560b3b203",
#                 "target": "https://www.7digital.com/artist/powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "purchase for download",
#                 "type-id": "f8319a2f-f824-4617-81c8-be6560b3b203",
#                 "target": "https://www.qobuz.com/gb-en/interpreter/powerwolf/download-streaming-albums",
#                 "direction": "forward"
#             },
#             {
#                 "type": "purchase for download",
#                 "type-id": "f8319a2f-f824-4617-81c8-be6560b3b203",
#                 "target": "https://music.apple.com/us/artist/272130237",
#                 "direction": "forward",
#                 "ended": "true"
#             },
#             {
#                 "type": "purchase for mail-order",
#                 "type-id": "611b1862-67af-4253-a64f-34adba305d1d",
#                 "target": "https://www.amazon.com/-/e/B005DKS2UM",
#                 "direction": "forward"
#             },
#             {
#                 "type": "purchase for mail-order",
#                 "type-id": "611b1862-67af-4253-a64f-34adba305d1d",
#                 "target": "https://www.cdjapan.co.jp/person/700721552",
#                 "direction": "forward"
#             },
#             {
#                 "type": "secondhandsongs",
#                 "type-id": "79c5b84d-a206-4f4c-9832-78c028c312c3",
#                 "target": "https://secondhandsongs.com/artist/76954",
#                 "direction": "forward"
#             },
#             {
#                 "type": "setlistfm",
#                 "type-id": "bf5d0d5e-27a1-4e94-9df7-3cdc67b3b207",
#                 "target": "https://www.setlist.fm/setlists/powerwolf-2bd7949a.html",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://plus.google.com/114468397654434232679",
#                 "direction": "forward",
#                 "end": "2019-04",
#                 "ended": "true"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://twitter.com/powerwolfband",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://www.facebook.com/powerwolfmetal",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://www.instagram.com/officialpowerwolf/",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://www.reverbnation.com/powerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://www.threads.com/@officialpowerwolf",
#                 "direction": "forward"
#             },
#             {
#                 "type": "social network",
#                 "type-id": "99429741-f3f6-484b-84f8-23af51991770",
#                 "target": "https://www.tiktok.com/@powerwolfmetal",
#                 "direction": "forward"
#             },
#             {
#                 "type": "songkick",
#                 "type-id": "aac9c4bc-a5b9-30b8-9839-e3ac314c6e58",
#                 "target": "https://www.songkick.com/artists/528716",
#                 "direction": "forward"
#             },
#             {
#                 "type": "soundcloud",
#                 "type-id": "89e4a949-0976-440d-bda1-5f772c1e5710",
#                 "target": "https://soundcloud.com/powerwolf-official",
#                 "direction": "forward"
#             },
#             {
#                 "type": "streaming",
#                 "type-id": "63cc5d1f-f096-4c94-a43f-ecb32ea94161",
#                 "target": "https://music.amazon.de/artists/B001SXJ0PO",
#                 "direction": "forward"
#             },
#             {
#                 "type": "streaming",
#                 "type-id": "63cc5d1f-f096-4c94-a43f-ecb32ea94161",
#                 "target": "https://music.apple.com/de/artist/272130237",
#                 "direction": "forward"
#             },
#             {
#                 "type": "streaming",
#                 "type-id": "63cc5d1f-f096-4c94-a43f-ecb32ea94161",
#                 "target": "https://music.apple.com/gb/artist/272130237",
#                 "direction": "forward"
#             },
#             {
#                 "type": "streaming",
#                 "type-id": "63cc5d1f-f096-4c94-a43f-ecb32ea94161",
#                 "target": "https://music.amazon.com/artists/B001FBLI3Q",
#                 "direction": "forward",
#                 "ended": "true"
#             },
#             {
#                 "type": "streaming",
#                 "type-id": "63cc5d1f-f096-4c94-a43f-ecb32ea94161",
#                 "target": "https://music.amazon.com/artists/B001SXJ0PO",
#                 "direction": "forward",
#                 "ended": "true"
#             },
#             {
#                 "type": "VIAF",
#                 "type-id": "e8571dcc-35d4-4e91-a577-a3382fd84460",
#                 "target": "http://viaf.org/viaf/125893555",
#                 "direction": "forward"
#             },
#             {
#                 "type": "wikidata",
#                 "type-id": "689870a4-a1e4-4912-b17f-7b2664215698",
#                 "target": "https://www.wikidata.org/wiki/Q706748",
#                 "direction": "forward"
#             },
#             {
#                 "type": "youtube",
#                 "type-id": "6a540e5b-58c6-4192-b6ba-dbc71ec8fcf0",
#                 "target": "https://www.youtube.com/user/Powerwolfmetal",
#                 "direction": "forward"
#             },
#             {
#                 "type": "youtube music",
#                 "type-id": "631712a0-7525-42ba-b7a3-605aa7a238c4",
#                 "target": "https://music.youtube.com/channel/UC9LO_ioQYQay7CrsbacNqBQ",
#                 "direction": "forward"
#             }
#         ],
#         "tag-list": [
#             {
#                 "count": "2",
#                 "name": "german"
#             },
#             {
#                 "count": "2",
#                 "name": "metal"
#             },
#             {
#                 "count": "16",
#                 "name": "power metal"
#             }
#         ]
#     }
# }

# %%
import pycountry

homepage = [link["target"] for link in links if link["type"] == "official homepage"][0]
country = pycountry.countries.get(alpha_2=artist["country"])
albums = [album["title"] for album in artist["release-group-list"] if album["primary-type"] == "Album" and "secondary-type-list" not in album]

print(tags)

# %%
print(f"Artist name = {artist['name']}")
print(f"Artist mbid = {artist['id']}")
print(f"Artist homepage = {homepage}")
print(f"Artist country = {country.name}")
print(f"Artist albums = {len(albums)}")
