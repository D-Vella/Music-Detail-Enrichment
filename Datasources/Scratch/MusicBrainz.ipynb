# %% [markdown]
# Documentaion link: https://python-musicbrainzngs.readthedocs.io/en/v0.7.1/usage/

# %%
# %pip install musicbrainzngs pycountry --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import musicbrainzngs as mb
mb.set_useragent("Music Detail Enrichment", "0.1", "https://github.com/D-Vella/music-detail-enrichment")
test_artist_name = "Call me Amour"
result = mb.search_artists(test_artist_name, limit=25)

# %%
import json
print(json.dumps(result, indent=2))
# Out:
# {
#   "artist-list": [
#     {
#       "id": "a4ac255f-9775-4c16-8642-7f51502e45dd",
#       "type": "Person",
#       "ext:score": "100",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "71e43d18-c6f2-4c6f-8026-5f85af905bcd",
#         "type": "City",
#         "name": "Portland",
#         "sort-name": "Portland",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "author",
#       "isni-list": [
#         "0000000120213263",
#         "0000000121446296"
#       ],
#       "life-span": {
#         "begin": "1947-09-21",
#         "ended": "false"
#       },
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "author"
#         },
#         {
#           "count": "1",
#           "name": "on writing"
#         },
#         {
#           "count": "1",
#           "name": "has german audio plays"
#         },
#         {
#           "count": "1",
#           "name": "horror"
#         },
#         {
#           "count": "1",
#           "name": "fantasy"
#         },
#         {
#           "count": "1",
#           "name": "has german audiobooks"
#         },
#         {
#           "count": "1",
#           "name": "writer"
#         },
#         {
#           "count": "1",
#           "name": "audiobook"
#         },
#         {
#           "count": "1",
#           "name": "audio drama"
#         }
#       ]
#     },
#     {
#       "id": "8bc6b7fb-9a38-4d0f-b055-f0ed33e55c9c",
#       "type": "Person",
#       "ext:score": "80",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "disambiguation": "production music composer",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "506c0105-a260-4b34-9251-08d782baf29c",
#       "type": "Person",
#       "ext:score": "78",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "14e7a419-ac00-4569-a2e9-c74f9ed47ff2",
#         "type": "City",
#         "name": "Champaign",
#         "sort-name": "Champaign",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "American gospel rapper",
#       "life-span": {
#         "begin": "1991-08-23",
#         "ended": "false"
#       }
#     },
#     {
#       "id": "34eeecf1-e605-44d3-a358-27cb27616b6e",
#       "type": "Person",
#       "ext:score": "78",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "area": {
#         "id": "7dc47ab9-c7ff-4282-97e0-bd53db80ff9d",
#         "type": "City",
#         "name": "Adelaide",
#         "sort-name": "Adelaide",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "DJ and producer from Adelaide, Australia",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "a95b1a75-474c-4d3d-9573-4dbe2cb0813d",
#       "type": "Person",
#       "ext:score": "78",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "organist and composer",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "2b96908e-e52c-4e68-9a86-e638fd4c0c2e",
#       "ext:score": "77",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "disambiguation": "management",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "f2dd139b-c573-4730-abc3-ba4d5a212ead",
#       "type": "Person",
#       "ext:score": "77",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "disambiguation": "rock vocalist",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "1ed33a3f-3f5e-4773-9356-ea2e2fa879ef",
#       "type": "Person",
#       "ext:score": "77",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "Connecticut keyboard player/vocalist",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "2942cf24-96d0-48d7-82ca-1a3133d12e6a",
#       "ext:score": "77",
#       "name": "Stephen King",
#       "sort-name": "King, Stephen",
#       "disambiguation": "hip hop producer",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "fad46635-5d90-484e-bcf9-5a8e3c1f8830",
#       "type": "Person",
#       "ext:score": "55",
#       "name": "Stephen Fry",
#       "sort-name": "Fry, Stephen",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "b0b860b3-35d3-414b-b734-7e5b1c41ea70",
#         "type": "District",
#         "name": "Hampstead",
#         "sort-name": "Hampstead",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "English comedian, actor, writer, presenter & activist",
#       "isni-list": [
#         "000000012129064X"
#       ],
#       "life-span": {
#         "begin": "1957-08-24",
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Fry, Stephen John",
#           "type": "Legal name",
#           "alias": "Stephen John Fry"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "british"
#         },
#         {
#           "count": "1",
#           "name": "english"
#         },
#         {
#           "count": "1",
#           "name": "non-musician"
#         },
#         {
#           "count": "2",
#           "name": "uk"
#         }
#       ]
#     },
#     {
#       "id": "46264289-6b22-4cc9-b6de-c456fe3ffbd6",
#       "type": "Person",
#       "ext:score": "52",
#       "name": "King Stephen",
#       "sort-name": "King Stephen",
#       "country": "VE",
#       "area": {
#         "id": "2ac90d6b-04fa-3006-8a91-89da01032365",
#         "type": "Country",
#         "name": "Venezuela",
#         "sort-name": "Venezuela",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "darksynth",
#       "life-span": {
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "KING STEPHEN",
#           "alias": "KING STEPHEN"
#         }
#       ]
#     },
#     {
#       "id": "a7e6de44-5c49-48db-8055-69bdac35fb3c",
#       "ext:score": "51",
#       "name": "Oracle Machine",
#       "sort-name": "Oracle Machine",
#       "disambiguation": "Stephen King psy",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "dcb03ce3-67a5-4eb3-b2d1-2a12d93a38f3",
#       "type": "Person",
#       "ext:score": "51",
#       "name": "B.B. King",
#       "sort-name": "King, B.B.",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "c6260041-8a63-45c1-ac3e-7976a3a84a74",
#         "type": "City",
#         "name": "Berclair",
#         "sort-name": "Berclair",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "end-area": {
#         "id": "cd22d0ba-c79b-45b3-a8e0-617b240df5f0",
#         "type": "City",
#         "name": "Las Vegas",
#         "sort-name": "Las Vegas",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "ipi-list": [
#         "00016240228"
#       ],
#       "isni-list": [
#         "0000000108886545"
#       ],
#       "life-span": {
#         "begin": "1925-09-16",
#         "end": "2015-05-14",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "locale": "en",
#           "sort-name": "King, B. B.",
#           "type": "Artist name",
#           "alias": "B. B. King"
#         },
#         {
#           "sort-name": "BB King",
#           "type": "Search hint",
#           "alias": "BB King"
#         },
#         {
#           "sort-name": "B.B.King",
#           "type": "Search hint",
#           "alias": "B.B.King"
#         },
#         {
#           "sort-name": "B B King",
#           "type": "Search hint",
#           "alias": "B B King"
#         },
#         {
#           "locale": "en",
#           "sort-name": "King, Riley B.",
#           "type": "Legal name",
#           "alias": "Riley B. King"
#         },
#         {
#           "sort-name": "King, B.B. & Ensemble",
#           "alias": "B.B. King & Ensemble"
#         },
#         {
#           "sort-name": "B.B. King & Friends",
#           "alias": "B.B. King & Friends"
#         },
#         {
#           "sort-name": "B.B. King Medley",
#           "alias": "B.B. King Medley"
#         },
#         {
#           "sort-name": "BB King and Friends",
#           "alias": "BB King and Friends"
#         },
#         {
#           "sort-name": "B.B. King and Friends",
#           "alias": "B.B. King and Friends"
#         },
#         {
#           "sort-name": "BB. King & Friends",
#           "alias": "BB. King & Friends"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "17",
#           "name": "blues"
#         },
#         {
#           "count": "1",
#           "name": "soul"
#         },
#         {
#           "count": "1",
#           "name": "blues rock"
#         },
#         {
#           "count": "4",
#           "name": "electric blues"
#         },
#         {
#           "count": "2",
#           "name": "soul blues"
#         },
#         {
#           "count": "1",
#           "name": "live"
#         },
#         {
#           "count": "1",
#           "name": "jazz and blues"
#         },
#         {
#           "count": "1",
#           "name": "urban blues"
#         },
#         {
#           "count": "2",
#           "name": "rhythm & blues"
#         },
#         {
#           "count": "1",
#           "name": "filmore"
#         },
#         {
#           "count": "2",
#           "name": "2008 universal fire victim"
#         }
#       ]
#     },
#     {
#       "id": "0f6757a2-1cb4-4e39-9ceb-95cc65e33eda",
#       "ext:score": "51",
#       "name": "Stephen King read by Jessie Mueller",
#       "sort-name": "Stephen King read by Jessie Mueller",
#       "life-span": {
#         "ended": "false"
#       }
#     },
#     {
#       "id": "b38225b8-8e5f-42aa-bcdc-7bae5b5bdab3",
#       "type": "Group",
#       "ext:score": "51",
#       "name": "King Crimson",
#       "sort-name": "King Crimson",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#         "type": "City",
#         "name": "London",
#         "sort-name": "London",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "isni-list": [
#         "0000000123245914"
#       ],
#       "life-span": {
#         "begin": "1968-11-30",
#         "end": "2021",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "locale": "ja",
#           "sort-name": "\u30ad\u30f3\u30b0\u30fb\u30af\u30ea\u30e0\u30be\u30f3",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u30ad\u30f3\u30b0\u30fb\u30af\u30ea\u30e0\u30be\u30f3"
#         },
#         {
#           "sort-name": "King Krimson",
#           "alias": "King Krimson"
#         },
#         {
#           "sort-name": "King Crimson, with Jon Anderso",
#           "alias": "King Crimson, with Jon Anderso"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "2",
#           "name": "rock"
#         },
#         {
#           "count": "22",
#           "name": "progressive rock"
#         },
#         {
#           "count": "-1",
#           "name": "jazz"
#         },
#         {
#           "count": "-1",
#           "name": "experimental"
#         },
#         {
#           "count": "3",
#           "name": "british"
#         },
#         {
#           "count": "0",
#           "name": "new wave"
#         },
#         {
#           "count": "0",
#           "name": "uk"
#         },
#         {
#           "count": "0",
#           "name": "improvisation"
#         },
#         {
#           "count": "1",
#           "name": "progressive"
#         },
#         {
#           "count": "7",
#           "name": "art rock"
#         },
#         {
#           "count": "0",
#           "name": "classic rock"
#         },
#         {
#           "count": "0",
#           "name": "abstract"
#         },
#         {
#           "count": "5",
#           "name": "experimental rock"
#         },
#         {
#           "count": "1",
#           "name": "symphonic rock"
#         },
#         {
#           "count": "4",
#           "name": "jazz fusion"
#         },
#         {
#           "count": "1",
#           "name": "avant-garde"
#         },
#         {
#           "count": "0",
#           "name": "english"
#         },
#         {
#           "count": "0",
#           "name": "england"
#         },
#         {
#           "count": "0",
#           "name": "united kingdom"
#         },
#         {
#           "count": "1",
#           "name": "symphonic prog"
#         },
#         {
#           "count": "-1",
#           "name": "pioneers"
#         },
#         {
#           "count": "-1",
#           "name": "classic pop and rock"
#         },
#         {
#           "count": "0",
#           "name": "eclectic"
#         },
#         {
#           "count": "4",
#           "name": "free improvisation"
#         },
#         {
#           "count": "0",
#           "name": "avant-prog"
#         },
#         {
#           "count": "0",
#           "name": "surreal"
#         },
#         {
#           "count": "-1",
#           "name": "progressif"
#         },
#         {
#           "count": "0",
#           "name": "anxious"
#         },
#         {
#           "count": "0",
#           "name": "eclectic prog"
#         },
#         {
#           "count": "0",
#           "name": "post-progressive"
#         },
#         {
#           "count": "0",
#           "name": "aln-sh"
#         },
#         {
#           "count": "0",
#           "name": "absent lovers"
#         }
#       ]
#     },
#     {
#       "id": "fbe054ec-a143-4101-9e9e-64abc5ff5ac9",
#       "type": "Person",
#       "ext:score": "50",
#       "name": "Nat King Cole",
#       "sort-name": "Cole, Nat King",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "2054b43f-446c-45fd-b53e-f8bf23656dd1",
#         "type": "City",
#         "name": "Montgomery",
#         "sort-name": "Montgomery",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "end-area": {
#         "id": "dbacf2e3-7e3e-4cee-8804-999b109285fa",
#         "type": "City",
#         "name": "Santa Monica",
#         "sort-name": "Santa Monica",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "ipi-list": [
#         "00006485981"
#       ],
#       "isni-list": [
#         "0000000114898972"
#       ],
#       "life-span": {
#         "begin": "1919-03-17",
#         "end": "1965-02-15",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Nat Kig Cole",
#           "alias": "Nat Kig Cole"
#         },
#         {
#           "sort-name": "Nat King Cloe",
#           "alias": "Nat King Cloe"
#         },
#         {
#           "sort-name": "Cole, King at the Piano with Rhythm",
#           "alias": "King Cole at the Piano with Rhythm"
#         },
#         {
#           "locale": "ja",
#           "sort-name": "\u30ca\u30c3\u30c8\u30fb\u30ad\u30f3\u30b0\u30fb\u30b3\u30fc\u30eb",
#           "type": "Artist name",
#           "alias": "\u30ca\u30c3\u30c8\u30fb\u30ad\u30f3\u30b0\u30fb\u30b3\u30fc\u30eb"
#         },
#         {
#           "sort-name": "Cole, Nat King",
#           "alias": "Cole, Nat King"
#         },
#         {
#           "sort-name": "Nat \"King\" Cole",
#           "alias": "Nat \"King\" Cole"
#         },
#         {
#           "sort-name": "Cole, Nat \"King\"",
#           "alias": "Cole, Nat \"King\""
#         },
#         {
#           "sort-name": "King Cole",
#           "alias": "King Cole"
#         },
#         {
#           "locale": "en",
#           "sort-name": "Nat 'King' Cole",
#           "type": "Artist name",
#           "alias": "Nat 'King' Cole"
#         },
#         {
#           "locale": "en",
#           "sort-name": "Cole, Nat",
#           "alias": "Nat Cole"
#         },
#         {
#           "sort-name": "Coles, Nathaniel Adams",
#           "type": "Legal name",
#           "alias": "Nathaniel Adams Coles"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "r&b"
#         },
#         {
#           "count": "2",
#           "name": "pop"
#         },
#         {
#           "count": "0",
#           "name": "american"
#         },
#         {
#           "count": "0",
#           "name": "usa"
#         },
#         {
#           "count": "0",
#           "name": "jump blues"
#         },
#         {
#           "count": "0",
#           "name": "easy listening soundtracks and musicals"
#         },
#         {
#           "count": "-1",
#           "name": "death by lung cancer"
#         },
#         {
#           "count": "2",
#           "name": "traditional pop"
#         },
#         {
#           "count": "2",
#           "name": "standards"
#         },
#         {
#           "count": "3",
#           "name": "easy listening"
#         },
#         {
#           "count": "3",
#           "name": "swing"
#         },
#         {
#           "count": "7",
#           "name": "jazz"
#         },
#         {
#           "count": "5",
#           "name": "vocal jazz"
#         },
#         {
#           "count": "1",
#           "name": "anthology"
#         }
#       ]
#     },
#     {
#       "id": "bf6c29f5-b69f-4842-9031-37f9645d365d",
#       "type": "Person",
#       "ext:score": "49",
#       "name": "Carole King",
#       "sort-name": "King, Carole",
#       "gender": "female",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "261962ea-d8c2-4eaf-a80c-f14376ffadb0",
#         "type": "District",
#         "name": "Manhattan",
#         "sort-name": "Manhattan",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "ipi-list": [
#         "00016226512",
#         "00056634861",
#         "00072763759"
#       ],
#       "isni-list": [
#         "0000000078290766",
#         "0000000368466336"
#       ],
#       "life-span": {
#         "begin": "1942-02-09",
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Carol King",
#           "alias": "Carol King"
#         },
#         {
#           "sort-name": "Klein, Carol Joan",
#           "type": "Legal name",
#           "end-date": "1959",
#           "alias": "Carol Joan Klein"
#         },
#         {
#           "locale": "ja",
#           "sort-name": "\u30ad\u30e3\u30ed\u30eb\u30fb\u30ad\u30f3\u30b0",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u30ad\u30e3\u30ed\u30eb\u30fb\u30ad\u30f3\u30b0"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "0",
#           "name": "classic pop and rock"
#         },
#         {
#           "count": "3",
#           "name": "folk"
#         },
#         {
#           "count": "3",
#           "name": "singer-songwriter"
#         },
#         {
#           "count": "0",
#           "name": "singer/songwriter"
#         },
#         {
#           "count": "1",
#           "name": "pop"
#         },
#         {
#           "count": "2",
#           "name": "brill building"
#         },
#         {
#           "count": "1",
#           "name": "soul"
#         },
#         {
#           "count": "4",
#           "name": "soft rock"
#         }
#       ]
#     },
#     {
#       "id": "6521b32f-3efb-4662-a0fa-c51f5897581b",
#       "type": "Person",
#       "ext:score": "49",
#       "name": "Stephen Hawking",
#       "sort-name": "Hawking, Stephen",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "33587495-c775-4483-b819-931c4cf438cd",
#         "type": "City",
#         "name": "Oxford",
#         "sort-name": "Oxford",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "end-area": {
#         "id": "11ba7f4f-3fb9-4b4b-a72f-ab1cd9c37d99",
#         "type": "City",
#         "name": "Cambridge",
#         "sort-name": "Cambridge",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "isni-list": [
#         "0000000121034996"
#       ],
#       "life-span": {
#         "begin": "1942-01-08",
#         "end": "2018-03-14",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "locale": "en",
#           "sort-name": "Hawking, Stephen William",
#           "type": "Legal name",
#           "alias": "Stephen William Hawking"
#         },
#         {
#           "locale": "en",
#           "sort-name": "Hawking, Stephen",
#           "type": "Artist name",
#           "alias": "Stephen Hawking"
#         },
#         {
#           "locale": "lt",
#           "sort-name": "Hokingas, Stivenas",
#           "type": "Artist name",
#           "alias": "Stivenas Hokingas"
#         },
#         {
#           "locale": "lt",
#           "sort-name": "Hokingas, Stivenas Viljamas",
#           "type": "Legal name",
#           "primary": "primary",
#           "alias": "Stivenas Viljamas Hokingas"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "2",
#           "name": "british"
#         },
#         {
#           "count": "1",
#           "name": "uk"
#         },
#         {
#           "count": "1",
#           "name": "english"
#         },
#         {
#           "count": "1",
#           "name": "physicist"
#         },
#         {
#           "count": "1",
#           "name": "has german audiobooks"
#         }
#       ]
#     },
#     {
#       "id": "01809552-4f87-45b0-afff-2c6f0730a3be",
#       "type": "Person",
#       "ext:score": "48",
#       "name": "Elvis Presley",
#       "sort-name": "Presley, Elvis",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "157e3c0e-1b68-403d-a515-6e37cb67947b",
#         "type": "City",
#         "name": "Tupelo",
#         "sort-name": "Tupelo",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "end-area": {
#         "id": "c2d96f61-75a4-4375-aed5-6aacb0b6326a",
#         "type": "City",
#         "name": "Memphis",
#         "sort-name": "Memphis",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "\u201cThe King of Rock and Roll\u201d",
#       "ipi-list": [
#         "00056021705",
#         "00056021803",
#         "00058226279"
#       ],
#       "isni-list": [
#         "0000000121241960",
#         "0000000368638871"
#       ],
#       "life-span": {
#         "begin": "1935-01-08",
#         "end": "1977-08-16",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "locale": "ru",
#           "sort-name": "\u041f\u0440\u0435\u0441\u043b\u0438, \u042d\u043b\u0432\u0438\u0441",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u042d\u043b\u0432\u0438\u0441 \u041f\u0440\u0435\u0441\u043b\u0438"
#         },
#         {
#           "locale": "tg",
#           "sort-name": "\u041f\u0440\u0435\u0441\u043b\u0438, \u042d\u043b\u0432\u0438\u0441",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u042d\u043b\u0432\u0438\u0441 \u041f\u0440\u0435\u0441\u043b\u0438"
#         },
#         {
#           "locale": "fa",
#           "sort-name": "\u067e\u0631\u0633\u0644\u06cc, \u0627\u0644\u0648\u06cc\u0633",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u0627\u0644\u0648\u06cc\u0633 \u067e\u0631\u0633\u0644\u06cc"
#         },
#         {
#           "locale": "uk",
#           "sort-name": "\u041f\u0440\u0435\u0441\u043b\u0456, \u0415\u043b\u0432\u0456\u0441",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u0415\u043b\u0432\u0456\u0441 \u041f\u0440\u0435\u0441\u043b\u0456"
#         },
#         {
#           "locale": "ar",
#           "sort-name": "\u0628\u0631\u064a\u0633\u0644\u064a, \u0625\u0644\u0641\u064a\u0633",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u0625\u0644\u0641\u064a\u0633 \u0628\u0631\u064a\u0633\u0644\u064a"
#         },
#         {
#           "locale": "yue",
#           "sort-name": "\u57c3\u723e\u7dad\u65af\u00b7\u76ae\u79ae\u58eb\u5229",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u57c3\u723e\u7dad\u65af\u00b7\u76ae\u79ae\u58eb\u5229"
#         },
#         {
#           "locale": "ja",
#           "sort-name": "\u30a8\u30eb\u30f4\u30a3\u30b9\u30fb\u30d7\u30ec\u30b9\u30ea\u30fc",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "\u30a8\u30eb\u30f4\u30a3\u30b9\u30fb\u30d7\u30ec\u30b9\u30ea\u30fc"
#         },
#         {
#           "sort-name": "The King",
#           "type": "Search hint",
#           "alias": "The King"
#         },
#         {
#           "sort-name": "Presley, Elvis Aaron",
#           "type": "Legal name",
#           "alias": "Elvis Aaron Presley"
#         },
#         {
#           "sort-name": "Presley, Elvis A.",
#           "alias": "Elvis A. Presley"
#         },
#         {
#           "locale": "en",
#           "sort-name": "Elvis",
#           "type": "Artist name",
#           "alias": "Elvis"
#         },
#         {
#           "sort-name": "Presley Elvis",
#           "alias": "Presley Elvis"
#         },
#         {
#           "sort-name": "The King of Rock and Roll",
#           "type": "Search hint",
#           "alias": "The King of Rock and Roll"
#         },
#         {
#           "sort-name": "Priesley",
#           "type": "Search hint",
#           "alias": "Priesley"
#         },
#         {
#           "locale": "en",
#           "sort-name": "Presley, Elvis",
#           "type": "Artist name",
#           "primary": "primary",
#           "alias": "Elvis Presley"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "6",
#           "name": "rock"
#         },
#         {
#           "count": "6",
#           "name": "pop"
#         },
#         {
#           "count": "-1",
#           "name": "american"
#         },
#         {
#           "count": "4",
#           "name": "blues"
#         },
#         {
#           "count": "-1",
#           "name": "singer"
#         },
#         {
#           "count": "10",
#           "name": "rockabilly"
#         },
#         {
#           "count": "6",
#           "name": "country"
#         },
#         {
#           "count": "2",
#           "name": "soul"
#         },
#         {
#           "count": "0",
#           "name": "rock n roll"
#         },
#         {
#           "count": "2",
#           "name": "pop rock"
#         },
#         {
#           "count": "4",
#           "name": "blue-eyed soul"
#         },
#         {
#           "count": "4",
#           "name": "gospel"
#         },
#         {
#           "count": "9",
#           "name": "rock and roll"
#         },
#         {
#           "count": "-1",
#           "name": "oldies"
#         },
#         {
#           "count": "-1",
#           "name": "love"
#         },
#         {
#           "count": "3",
#           "name": "film soundtrack"
#         },
#         {
#           "count": "-2",
#           "name": "classic pop and rock"
#         },
#         {
#           "count": "-1",
#           "name": "party"
#         },
#         {
#           "count": "-1",
#           "name": "best"
#         },
#         {
#           "count": "1",
#           "name": "singers"
#         },
#         {
#           "count": "2",
#           "name": "christmas music"
#         },
#         {
#           "count": "2",
#           "name": "actors"
#         },
#         {
#           "count": "1",
#           "name": "guitarists"
#         },
#         {
#           "count": "2",
#           "name": "r&b"
#         },
#         {
#           "count": "3",
#           "name": "rock & roll"
#         },
#         {
#           "count": "-2",
#           "name": "pop/rock"
#         },
#         {
#           "count": "-1",
#           "name": "flaming"
#         },
#         {
#           "count": "-1",
#           "name": "if you talk in your sleep"
#         },
#         {
#           "count": "-1",
#           "name": "in the studio"
#         },
#         {
#           "count": "-1",
#           "name": "eddie rubin"
#         },
#         {
#           "count": "1",
#           "name": "rock-and-roll"
#         },
#         {
#           "count": "0",
#           "name": "aln-sh"
#         },
#         {
#           "count": "1",
#           "name": "rock musicians"
#         },
#         {
#           "count": "2",
#           "name": "https://musicbrainz.org/artist/01809552-4f87-45b0-afff-2c6f0730a3be"
#         }
#       ]
#     },
#     {
#       "id": "26a30473-c754-4171-bccd-8674ed3cddcc",
#       "type": "Person",
#       "ext:score": "48",
#       "name": "King Stephen",
#       "sort-name": "King Stephen",
#       "disambiguation": "vocalist Algenard Herring",
#       "life-span": {
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Herring, Algenard",
#           "type": "Legal name",
#           "alias": "Algenard Herring"
#         }
#       ]
#     },
#     {
#       "id": "adad4d39-c1e6-4533-b4dc-76e6ac328299",
#       "type": "Person",
#       "ext:score": "48",
#       "name": "Stephen Mallinder",
#       "sort-name": "Mallinder, Stephen",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "3ce737cb-f5bb-403d-a98a-e0602670229f",
#         "type": "City",
#         "name": "Sheffield",
#         "sort-name": "Sheffield",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "member of Cabaret Voltaire",
#       "isni-list": [
#         "0000000055465375"
#       ],
#       "life-span": {
#         "begin": "1955-01-01",
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Mallinder, Stephen William",
#           "type": "Legal name",
#           "alias": "Stephen William Mallinder"
#         },
#         {
#           "sort-name": "King, Tennessee",
#           "alias": "Tennessee King"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "electronic"
#         },
#         {
#           "count": "1",
#           "name": "house"
#         },
#         {
#           "count": "1",
#           "name": "techno"
#         },
#         {
#           "count": "1",
#           "name": "leftfield dance"
#         },
#         {
#           "count": "1",
#           "name": "experimental electronic"
#         }
#       ]
#     },
#     {
#       "id": "bcd6af9f-afa8-43fd-b1be-acbbbb2f7dc7",
#       "type": "Person",
#       "ext:score": "48",
#       "name": "Stephen Sondheim",
#       "sort-name": "Sondheim, Stephen",
#       "gender": "male",
#       "country": "US",
#       "area": {
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "type": "Country",
#         "name": "United States",
#         "sort-name": "United States",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "74e50e58-5deb-4b99-93a2-decbb365c07f",
#         "type": "City",
#         "name": "New York",
#         "sort-name": "New York",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "end-area": {
#         "id": "d84671cc-540a-4e31-bd8f-59931c977b99",
#         "type": "City",
#         "name": "Roxbury",
#         "sort-name": "Roxbury",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "ipi-list": [
#         "00029156483"
#       ],
#       "isni-list": [
#         "0000000120968578"
#       ],
#       "life-span": {
#         "begin": "1930-03-22",
#         "end": "2021-11-26",
#         "ended": "true"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Steven Sondheim",
#           "alias": "Steven Sondheim"
#         },
#         {
#           "sort-name": "Sondheim, Stephen Joshua",
#           "type": "Legal name",
#           "alias": "Stephen Joshua Sondheim"
#         },
#         {
#           "sort-name": "Sondheim",
#           "alias": "Sondheim"
#         },
#         {
#           "locale": "lv",
#           "sort-name": "Sondheims, S.",
#           "alias": "S.Sondheims"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "classical"
#         },
#         {
#           "count": "1",
#           "name": "american"
#         },
#         {
#           "count": "1",
#           "name": "musical theatre"
#         }
#       ]
#     },
#     {
#       "id": "19585101-8735-4df6-bc77-c3435862f303",
#       "type": "Person",
#       "ext:score": "47",
#       "name": "Terry Devine-King",
#       "sort-name": "Devine-King, Terry",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "production music",
#       "ipi-list": [
#         "00159791619"
#       ],
#       "life-span": {
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "Terry H. Devine-King",
#           "alias": "Terry H. Devine-King"
#         },
#         {
#           "sort-name": "Terry Devine King",
#           "alias": "Terry Devine King"
#         },
#         {
#           "sort-name": "Terry Howard Devine-King",
#           "type": "Legal name",
#           "alias": "Terry Howard Devine-King"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "1",
#           "name": "media music"
#         }
#       ]
#     },
#     {
#       "id": "f58384a4-2ad2-4f24-89c5-c7b74ae1cce7",
#       "type": "Group",
#       "ext:score": "47",
#       "name": "King Gizzard & the Lizard Wizard",
#       "sort-name": "King Gizzard & the Lizard Wizard",
#       "country": "AU",
#       "area": {
#         "id": "106e0bec-b638-3b37-b731-f53d507dc00e",
#         "type": "Country",
#         "name": "Australia",
#         "sort-name": "Australia",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "b4e9352c-8edf-4911-8fa3-e852afa30501",
#         "type": "City",
#         "name": "Melbourne",
#         "sort-name": "Melbourne",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "isni-list": [
#         "000000047122567X"
#       ],
#       "life-span": {
#         "begin": "2010",
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "sort-name": "King Gizzard and the Lizard Wizard",
#           "alias": "King Gizzard and the Lizard Wizard"
#         },
#         {
#           "sort-name": "KGLW",
#           "type": "Search hint",
#           "alias": "KGLW"
#         },
#         {
#           "sort-name": "King Gizzard",
#           "type": "Search hint",
#           "alias": "King Gizzard"
#         },
#         {
#           "sort-name": "King Gizz",
#           "type": "Search hint",
#           "alias": "King Gizz"
#         }
#       ],
#       "tag-list": [
#         {
#           "count": "11",
#           "name": "progressive rock"
#         },
#         {
#           "count": "0",
#           "name": "heavy metal"
#         },
#         {
#           "count": "5",
#           "name": "thrash metal"
#         },
#         {
#           "count": "1",
#           "name": "australian"
#         },
#         {
#           "count": "2",
#           "name": "experimental"
#         },
#         {
#           "count": "1",
#           "name": "hard rock"
#         },
#         {
#           "count": "1",
#           "name": "synth-pop"
#         },
#         {
#           "count": "8",
#           "name": "jazz rock"
#         },
#         {
#           "count": "-1",
#           "name": "lo-fi"
#         },
#         {
#           "count": "24",
#           "name": "psychedelic rock"
#         },
#         {
#           "count": "-1",
#           "name": "psychedelic"
#         },
#         {
#           "count": "5",
#           "name": "psychedelic pop"
#         },
#         {
#           "count": "15",
#           "name": "garage rock"
#         },
#         {
#           "count": "4",
#           "name": "neo-psychedelia"
#         },
#         {
#           "count": "4",
#           "name": "surf rock"
#         },
#         {
#           "count": "1",
#           "name": "boogie rock"
#         },
#         {
#           "count": "-1",
#           "name": "australia"
#         },
#         {
#           "count": "3",
#           "name": "heavy psych"
#         },
#         {
#           "count": "1",
#           "name": "spotify boycott"
#         }
#       ]
#     },
#     {
#       "id": "d3f41b0f-0edc-4b57-b1b6-c5fe359f4209",
#       "type": "Person",
#       "ext:score": "46",
#       "name": "Stephen Briggs",
#       "sort-name": "Briggs, Stephen",
#       "gender": "male",
#       "country": "GB",
#       "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "type": "Country",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "begin-area": {
#         "id": "33587495-c775-4483-b819-931c4cf438cd",
#         "type": "City",
#         "name": "Oxford",
#         "sort-name": "Oxford",
#         "life-span": {
#           "ended": "false"
#         }
#       },
#       "disambiguation": "British writer and audiobook reader",
#       "isni-list": [
#         "0000000117516562"
#       ],
#       "life-span": {
#         "begin": "1951-12-04",
#         "ended": "false"
#       },
#       "alias-list": [
#         {
#           "locale": "en",
#           "sort-name": "Briggs, Stephen Charles",
#           "type": "Artist name",
#           "alias": "Stephen Charles Briggs"
#         }
#       ]
#     }
#   ],
#   "artist-count": 14034
# }

# %%
result = mb.search_artists(test_artist_name, limit=5)
cleaned_results = []
for artist in result['artist-list']:
    cleaned_results.append({
        'id': artist['id'],
        'name': artist['name'],
        'score': artist.get('ext:score', 0)
    })
for artist in cleaned_results:
    if int(artist['score']) >= 85:
        print(f"{artist['id']}: {artist['name']} - {artist['score']}")
# Out:
# 89e39f67-65cc-4f90-b145-b1b56c209f8a: Craig David - 100

# %%
import json

artist_id = "3ef77bdc-b1ce-4e44-aa4b-acfa763c5284"
try:
    result = mb.get_artist_by_id(artist_id,includes=["release-groups","url-rels","tags"],release_type=["album"])
except mb.WebServiceError as exc:
    print("Something went wrong with the request: %s" % exc)
else:
    artist = result["artist"]
    tags = artist["tag-list"]
    links = artist["url-relation-list"]

    print(json.dumps(result, indent=4))

# %%
import pycountry

homepage = [link["target"] for link in links if link["type"] == "official homepage"][0]
country = pycountry.countries.get(alpha_2=artist["country"])
albums = [album["title"] for album in artist["release-group-list"] if album["primary-type"] == "Album" and "secondary-type-list" not in album]

print(tags)

# %%
print(f"Artist name = {artist['name']}")
print(f"Artist mbid = {artist['id']}")
print(f"Artist homepage = {homepage}")
print(f"Artist country = {country.name}")
print(f"Artist albums = {len(albums)}")
