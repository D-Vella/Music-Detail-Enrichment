# %% [markdown]
# #get the database data from Notion
# #Filter Data to relevent place
# #Query Music Brainz for information
# #Update Notion with information.

# %%
# %pip install python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv('.env')
token = os.getenv('API_TOKEN')
print(token)
# Out:
# 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

# %%
import requests
import base64
import json

database_id = '3386e950cac68076b55af3942ff2dfa7'
url = f"https://api.notion.com/v1/databases/{database_id}"
api_ver = '2026-03-11'


headers = {
    "Notion-Version": f"{api_ver}",
    "Authorization": f"Bearer {token}"
}

response = requests.get(url, headers=headers)
datasource_id = response.json()['data_sources'][0]['id']
print(datasource_id)
# Out:
# 3386e950-cac6-80d4-9271-000b73bb2473

# %%
#Get datasource details:
datasource_url = f"https://api.notion.com/v1/data_sources/{datasource_id}"
response = requests.get(datasource_url, headers=headers)
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "object": "data_source",
#     "id": "3386e950-cac6-80d4-9271-000b73bb2473",
#     "cover": null,
#     "icon": null,
#     "created_time": "2026-04-04T12:27:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "92ab7ca2-ce9c-4cdd-9c9f-6dc24dc56e88"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "92ab7ca2-ce9c-4cdd-9c9f-6dc24dc56e88"
#     },
#     "last_edited_time": "2026-04-05T18:37:00.000Z",
#     "title": [
#         {
#             "type": "text",
#             "text": {
#                 "content": "Band and artist tracker",
#                 "link": null
#             },
#             "annotations": {
#                 "bold": false,
#                 "italic": false,
#                 "strikethrough": false,
#                 "underline": false,
#                 "code": false,
#                 "color": "default"
#             },
#             "plain_text": "Band and artist tracker",
#             "href": null
# ...

# %%
#Query datasource:
datasource_url = f"https://api.notion.com/v1/data_sources/{datasource_id}/query"
fields_list = ['title','Country','Label','Website','Genre']
params = {
    'filter_properties[]': ['title', 'Country', 'Label', 'Website', 'Genre']
}
payload = {
    "sorts": [
        {
            "property": "title",
            "direction": "ascending"
        }
    ],
    "page_size": 10,
    "in_trash": False,
    "result_type": "page"
}

response = requests.post(datasource_url, headers=headers, json=payload, params=params)
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "object": "list",
#     "results": [
#         {
#             "object": "page",
#             "id": "3396e950-cac6-8084-b20c-d3660c4206b0",
#             "created_time": "2026-04-05T14:46:00.000Z",
#             "last_edited_time": "2026-04-05T14:47:00.000Z",
#             "created_by": {
#                 "object": "user",
#                 "id": "92ab7ca2-ce9c-4cdd-9c9f-6dc24dc56e88"
#             },
#             "last_edited_by": {
#                 "object": "user",
#                 "id": "92ab7ca2-ce9c-4cdd-9c9f-6dc24dc56e88"
#             },
#             "cover": null,
#             "icon": null,
#             "parent": {
#                 "type": "data_source_id",
#                 "data_source_id": "3386e950-cac6-80d4-9271-000b73bb2473",
#                 "database_id": "3386e950-cac6-8076-b55a-f3942ff2dfa7"
#             },
#             "in_trash": false,
#             "is_archived": false,
#             "is_locked": false,
#             "properties": {
# ...
