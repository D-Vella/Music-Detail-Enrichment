# %% [markdown]
# #get the database data from Notion
# #Filter Data to relevent place
# #Query Music Brainz for information
# #Update Notion with information.

# %%
import requests
import base64
database_id = 'Bands-and-Artists-3386e950cac680c1a816d65cc4a889bb'
url = f"https://api.notion.com/v1/databases/{database_id}"
api_ver = '2026-03-11'

token = ''
token_encoded = base64.b64encode(token.encode()).decode()

headers = {
    "Notion-Version": f"{api_ver}",
    "Authorization": "Bearer {token_encoded}"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"object":"error","status":401,"code":"unauthorized","message":"API token is invalid.","request_id":"1ad561df-170f-487e-8d10-af5f7c907ed6"}
